# %% [markdown]
# # My Jupyter Botebook on IBM Watson Studio

# %% [markdown]
# **Tom**
#
# My occupation is junior consultant

# %% [markdown]
# *I am interested in data science because every project that you do is different. Where one project concerns visualization and dashboarding, the next converns a difficult AI project. This diversity keeps me going.*

# %% [markdown]
# ### In the next cell, my code will do 1+1, showing the output of 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# bulleted list
# * item 1
# * item 2
# * item 3
#
# horizontal rule:
#
# ***
#
# numbered list
# 1. item 1
# 1. item 2
# 1. item 3
#
# hyperlink: __[Coursera Course](https://www.coursera.org/learn/open-source-tools-for-data-science)__
#
# table
#
# | header | header |
# | ----- | ----- |
# | item 1
